# %% [markdown]
# <a href="https://colab.research.google.com/github/jonitodev/PembelajaranMesin/blob/main/JS03/JS03_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Langkah 0 - Instal Library

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.13/dist-packages (11.3.0)

# %% [markdown]
# # Langkah 1 - Load Image

# %%
	from PIL import Image

	img = Image.open('bahlil.jpg')
	img.show() # tampilkan gambar
	display(img) # metode alternatif tampilkan gambar
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x558>

# %% [markdown]
# # Langkah 2 - Ekstrak Fitur

# %%
	# Ekstrak setiap channel red, green, blue
	r, g, b = img.split()

	# Cek panjang ukuran channel red
	print(len(r.histogram()))

	# Cetak fitur histogram pada channel red
	print(r.histogram())
# Out:
# 256
# [14, 7, 5, 6, 6, 10, 15, 9, 16, 13, 13, 26, 20, 20, 28, 31, 29, 28, 46, 33, 46, 56, 58, 55, 73, 59, 81, 108, 115, 139, 159, 187, 207, 241, 301, 333, 472, 520, 620, 772, 884, 998, 1095, 1301, 1464, 1614, 1733, 1892, 2095, 2145, 2197, 2403, 2526, 2436, 2476, 2443, 2369, 2310, 2232, 2093, 1908, 1763, 1620, 1491, 1346, 1197, 1076, 954, 872, 698, 634, 586, 515, 424, 404, 343, 313, 261, 266, 222, 239, 202, 229, 163, 178, 174, 181, 190, 135, 161, 179, 136, 157, 147, 154, 150, 133, 182, 137, 160, 163, 147, 157, 144, 162, 176, 167, 150, 170, 176, 212, 181, 195, 187, 189, 173, 200, 199, 191, 170, 201, 215, 164, 214, 214, 198, 221, 230, 247, 252, 264, 286, 280, 249, 285, 284, 258, 290, 299, 291, 274, 329, 315, 306, 328, 314, 322, 327, 333, 332, 314, 353, 359, 350, 366, 375, 384, 355, 398, 387, 399, 422, 446, 427, 460, 457, 475, 493, 531, 552, 534, 583, 604, 587, 640, 688, 684, 686, 753, 679, 748, 777, 791, 862, 913, 873, 983, 990, 1054, 1081, 1067, 1129, 1157, 1147, 1289, 1263, 1240, 1274, 1285, 1353, 1336, 1250, 1293, 1420, 1314, 1271, 1206, 1211, 1142, 1201, 1066, 1015, 937, 877, 853, 828, 754, 713, 663, 596, 574, 573, 519, 506, 433, 405, 395, 381, 318, 318, 305, 268, 265, 248, 230, 237, 262, 251, 241, 252, 296, 319, 323, 366, 367, 450, 485, 621, 746, 1041, 1319, 1666, 1988, 2151, 4212, 123112]
